# %%
import pandas as pd

# %%
ufo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/ufo.csv')

# %%
ufo.head()
ufo.columns = ufo.columns.str.replace(' ','_')

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
booleans = []
for i in ufo.Shape_Reported:
    if i == 'LIGHT':
        booleans.append(True)
    else:
        booleans.append(False)

# %%
ufo.head()
# Out:
#                    City Colors_Reported Shape_Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
booleans[0:5]
# Out:
# [False, False, False, False, True]

# %%
len(booleans)
# Out:
# 18241

# %%
shape_light = pd.Series(booleans)

# %%
shape_light.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
ufo[shape_light]##passed in list of bools and will only show bool = 1
# Out:
#                        City Colors_Reported Shape_Reported State  \
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 10                  Fontana             NaN          LIGHT    CA
# 22                      NaN             NaN          LIGHT    LA
# 54                Cleveland             NaN          LIGHT    OH
# 86                Henrietta             NaN          LIGHT    OK
# 95                     Ojai             NaN          LIGHT    CA
# 101                   Grays             NaN          LIGHT    SC
# 110             Mill Valley             NaN          LIGHT    CA
# 116            Lackland AFB             NaN          LIGHT    TX
# 137                Florence             NaN          LIGHT    CO
# 139           Bay St. Louis             NaN          LIGHT    MS
# 140          East Palestine             NaN          LIGHT    OH
# 191                   Miami             NaN          LIGHT    FL
# ...

# %%
new_light = ufo.Shape_Reported == 'LIGHT'##series compare

# %%
new_light.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: Shape_Reported, dtype: bool

# %%
ufo[ufo.Shape_Reported == 'LIGHT']##act as a if
# Out:
#                        City Colors_Reported Shape_Reported State  \
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 10                  Fontana             NaN          LIGHT    CA
# 22                      NaN             NaN          LIGHT    LA
# 54                Cleveland             NaN          LIGHT    OH
# 86                Henrietta             NaN          LIGHT    OK
# 95                     Ojai             NaN          LIGHT    CA
# 101                   Grays             NaN          LIGHT    SC
# 110             Mill Valley             NaN          LIGHT    CA
# 116            Lackland AFB             NaN          LIGHT    TX
# 137                Florence             NaN          LIGHT    CO
# 139           Bay St. Louis             NaN          LIGHT    MS
# 140          East Palestine             NaN          LIGHT    OH
# 191                   Miami             NaN          LIGHT    FL
# ...

# %%
test=ufo[(ufo.Shape_Reported == 'LIGHT')]

# %%
test[test.Colors_Reported == 'ORANGE']
# Out:
#                   City Colors_Reported Shape_Reported State              Time
# 1256       Spartanburg          ORANGE          LIGHT    SC   6/30/1966 21:00
# 1995           Lansing          ORANGE          LIGHT    MI   7/11/1970 20:30
# 2214        Texas City          ORANGE          LIGHT    TX    6/1/1972 22:00
# 2256        Greensboro          ORANGE          LIGHT    NC   6/30/1972 21:00
# 2429             Perth          ORANGE          LIGHT    NY    7/1/1973 20:00
# 2659         Gibralter          ORANGE          LIGHT    MI    6/20/1974 1:00
# 2713    East Berkshire          ORANGE          LIGHT    VT   7/24/1974 21:00
# 3538       Waitesfield          ORANGE          LIGHT    VT    6/29/1977 3:00
# 3873             Union          ORANGE          LIGHT    MO   7/26/1978 20:00
# 3936       Leavenworth          ORANGE          LIGHT    KS    9/2/1978 21:00
# 6572           Brawley          ORANGE          LIGHT    CA    6/5/1991 17:00
# ...
